# %%
import requests
import json
import pandas as pd

# %%
API_KEY = "249692506407e84b97df60a1fae8891f"  # paste your RapidAPI key here

headers = {
    "x-rapidapi-host": "v3.football.api-sports.io",  # host as defined by RapidAPI :contentReference[oaicite:5]{index=5}
    "x-rapidapi-key": API_KEY                        # your personal API key :contentReference[oaicite:6]{index=6}
}
fixture_id = 1234  # example fixture ID
url = f"https://v3.football.api-sports.io/statistics/fixture/{fixture_id}"

response = requests.get(url, headers=headers)
match_stats = response.json()

print(json.dumps(match_stats, indent=2))
# Out:
# {
#   "get": "statistics/fixture/1234",
#   "parameters": [],
#   "errors": {
#     "endpoint": "The Statistics endpoint does not exist."
#   },
#   "results": 0,
#   "paging": {
#     "current": 1,
#     "total": 1
#   },
#   "response": []
# }
